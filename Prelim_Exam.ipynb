# %% [markdown]
# <a href="https://colab.research.google.com/github/Scwain/Numerical-Methods/blob/main/Prelim_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

A = np.array([
      [1,2,3],
      [2,3,3],
      [3,4,-2]        
])

print(round(np.linalg.det(A)))
# Out:
# 5
